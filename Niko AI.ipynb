# %% [markdown]
# run this cell to setup everything ONLY RUN IT ONCE cuz it take along time

# %%
# %tensorflow_version 1.x
# !pip install -q gpt-2-simple
# !pip install -q pyunpack
# !pip install -q patool

from os import path
import gpt_2_simple as gpt2
from datetime import datetime
from google.colab import files
import tensorflow as tf
import time
from pyunpack import Archive
import os


if not path.exists("checkpoint"):
  # !gdown --id 1FvRmN_gbGhvdekNWuajLl1_cwyOEKBuG
  Archive("checkpoint.zip").extractall(".")
  os.remove("checkpoint.zip")

if not path.exists("models"):
  gpt2.download_gpt2(model_name="355M")

tf.reset_default_graph()
session = gpt2.start_tf_sess()
gpt2.load_gpt2(session, run_name='run1')
# Out:
# Loading checkpoint checkpoint/run1/model-10000
# INFO:tensorflow:Restoring parameters from checkpoint/run1/model-10000

# %% [markdown]
# run this cell to generate texts

# %%
for i in range(0,5):
  result = gpt2.generate(session,
                model_name="355M",
                length=20,
                prefix="player is",
                temperature=0.7,
                nsamples=1,
                batch_size=1,
                truncate="<|endoftext|>",
                return_as_list=True
  )[0]
  print(result)
  print(" ")
# Out:
# player is out of film now...
#
#
# player is the same as mine!
#
#
# player is really taking it with me.
#
#
# player is a robot and not a boat...
#
#
# player is, now?
